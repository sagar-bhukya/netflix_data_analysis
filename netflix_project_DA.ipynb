# %% [markdown]
# Netflix Dataset cleaning project with using pandas

# %% [markdown]
# the dataset collected from third-party kaggle website which is free

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

data=pd.read_csv("netflix_dataset.csv")

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# Getting Some basic information about the netflix dataset

# %% [markdown]
# 1.head()

# %%
data.head()    # to show the top 5 records of the dataset
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# 2.head(how much rows do you want)

# %%
data.head(2)   #how much rows do you want from top
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %% [markdown]
# 3.tail()

# %%
data.tail()   # to show the bottom 5 records of the dataset
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %% [markdown]
# 4.tail(how much rows do you want from bottom)

# %%
data.tail(3)
# Out:
#      show_id   type       title         director  \
# 8804   s8805  Movie  Zombieland  Ruben Fleischer
# 8805   s8806  Movie        Zoom     Peter Hewitt
# 8806   s8807  Movie      Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#             date_added  release_year rating duration  \
# 8804  November 1, 2019          2009      R   88 min
# 8805  January 11, 2020          2006     PG   88 min
# 8806     March 2, 2019          2015  TV-14  111 min
#
#                                            listed_in  \
# 8804                         Comedies, Horror Movies
# 8805              Children & Family Movies, Comedies
# 8806  Dramas, International Movies, Music & Musicals
#
# ...

# %% [markdown]
# 5.Shape()

# %%
data.shape    # to show the No.of rows and columns
# Out:
# (8807, 12)

# %% [markdown]
# 6.Size

# %%
data.size     #to show the No.of total values (elements) in the dataset
# Out:
# 105684

# %% [markdown]
# 7.columns: to know the all columns in dataset

# %%
data.columns    #to show each column name
data.columns.to_list()   #gives in a list
# Out:
# ['show_id',
#  'type',
#  'title',
#  'director',
#  'cast',
#  'country',
#  'date_added',
#  'release_year',
#  'rating',
#  'duration',
#  'listed_in',
#  'description']

# %% [markdown]
# 8.dtypes

# %%
data.dtypes   # tells datatype of each column
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# 9.info

# %%
data.info()  #to show indexes, columns,datatypes of each column,memory at once and Null and not null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# Task 1: Is there any duplicate Records in this dataset? If yess, then remove the duplicates records.

# %% [markdown]
# duplicate()

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.shape
# Out:
# (8807, 12)

# %%
data[data.duplicated()]   # to know what are the duplicates records
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
data.drop_duplicates(inplace=True)  # for permanent duplicate delete
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# Task2: is there any null value present in any colum? show with Heat-map.

# %% [markdown]
# isnull()

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
data.isnull() # to show where the null value is present   .. where True=is null present
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
data.isnull().sum()   # to get how many null values present in each cloumn
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# seaborn library (heat-map)

# %%
import seaborn as sns # to import seaborn library
sns.heatmap(data.isnull()) # USing heatmap to show null values
# Out:
# <Axes: >

# %% [markdown]
# 1:for 'House of Cards',what is the show id and who is the Director of this show?

# %% [markdown]
# isin()

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data[data['title'].isin(['House of Cards'])]   # to show all records of a particular item of a column
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %% [markdown]
# str.contains()

# %%
data[data['title'].str.contains('House of Cards')] # to show all records  of a particular string in any column]
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %% [markdown]
# 2.In which year highest numbers of the TV shows & movies were released? show with Bar graph

# %% [markdown]
# dtypes

# %%
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# to_datatime

# %%
data['Data_N']=pd.to_datetime(data['release_year'])

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data['release_year'].duplicated(keep='first')
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 8802     True
# 8803     True
# 8804     True
# 8805     True
# 8806     True
# Name: release_year, Length: 8807, dtype: bool

# %% [markdown]
# dt.year.value_couts() : extract for year only from ex: 01-12-2021.....datatype =Datetime
# value_counts(): when there is only year present------int

# %%
data['release_year'].value_counts()
# Out:
# release_year
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: count, Length: 74, dtype: int64

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data['release_year'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='release_year'>

# %% [markdown]
# 3.How many movies and TV shows are in the dataset? show with Bar graph.

# %% [markdown]
# groupby()

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  \
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
#
#                          Data_N
# 0 1970-01-01 00:00:00.000002020
# ...

# %%
data.groupby('type').type.count()    # To group all unique items of a column and show their count
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %% [markdown]
# countplot()

# %%
sns.countplot(data['type'])  # To show the count of all unique values of any column in the form of a bar graph
# Out:
# <Axes: xlabel='count', ylabel='type'>

# %% [markdown]
# 4.Show all the movies that were released in the year 2021

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# filtering

# %%
data[(data['type']=='Movie')&(data['release_year']==2021)]
# Out:
#      show_id   type                                              title  \
# 6         s7  Movie                   My Little Pony: A New Generation
# 9        s10  Movie                                       The Starling
# 12       s13  Movie                                       Je Suis Karl
# 13       s14  Movie                   Confessions of an Invisible Girl
# 18       s19  Movie                                          Intrusion
# ...      ...    ...                                                ...
# 1425   s1426  Movie                        Creating The Queen's Gambit
# 1431   s1432  Movie                                        Stuck Apart
# 1436   s1437  Movie  Ratones Paranoicos: The Band that Rocked Argen...
# 1466   s1467  Movie                       The Minimalists: Less Is Now
# 1468   s1469  Movie                          What Happened to Mr. Cha?
#
#                              director  \
# 6       Robert Cullen, José Luis Ucha
# ...

# %% [markdown]
# 5.Show only the titles of all TV shows that were released in india only

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data[(data['type']=='TV Show')&(data['country']=="India")]['title']
# Out:
# 4                             Kota Factory
# 39                            Chhota Bheem
# 50                           Dharmakshetra
# 66           Raja Rasoi Aur Anya Kahaniyan
# 69          Stories by Rabindranath Tagore
#                        ...
# 8173                             Thackeray
# 8235                           The Calling
# 8321    The Golden Years with Javed Akhtar
# 8349                The House That Made Me
# 8775                       Yeh Meri Family
# Name: title, Length: 79, dtype: object

# %% [markdown]
# 6.show top 10 directors, who gave the highest number of TV shows & Movies to netflix?

# %% [markdown]
# value_count()

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data['director'].value_counts().head(10)
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: count, dtype: int64

# %% [markdown]
# 7.show all the records where "type is Movie and type is commedians" or "country is United Kingdom"

# %% [markdown]
# Filtering (And, Or operators)

# %%
data.head(4)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
#
# ...

# %%
data[(data['type']=="Movie") & (data['listed_in']=="Comedies")]
# Out:
#      show_id   type                                   title  \
# 27       s28  Movie                               Grown Ups
# 152     s153  Movie           Janoskians: Untold and Untrue
# 182     s183  Movie             Welcome Home Roscoe Jenkins
# 342     s343  Movie                             Major Payne
# 348     s349  Movie                                    Poms
# ...      ...    ...                                     ...
# 8420   s8421  Movie              The Men Who Stare at Goats
# 8433   s8434  Movie  The Naked Gun 2 1/2: The Smell of Fear
# 8536   s8537  Movie                       The Trip to Spain
# 8608   s8609  Movie                        Total Frat Movie
# 8730   s8731  Movie                       Where's the Money
#
#                   director                                               cast  \
# 27            Dennis Dugan  Adam Sandler, Kevin James, Chris Rock, David S...
# 152           Brett Weiner  Jai Brooks, Luke Brooks, James Yammouni, Danie...
# ...

# %%
data[((data['type']=="Movie") & (data['listed_in']=="Comedies")) | (data['country']=="United States")]
# Out:
#      show_id     type                 title         director  \
# 0         s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 9        s10    Movie          The Starling   Theodore Melfi
# 15       s16  TV Show     Dear White People              NaN
# 27       s28    Movie             Grown Ups     Dennis Dugan
# 28       s29    Movie            Dark Skies    Scott Stewart
# ...      ...      ...                   ...              ...
# 8791   s8792    Movie           Young Adult    Jason Reitman
# 8793   s8794    Movie  Yours, Mine and Ours     Raja Gosnell
# 8802   s8803    Movie                Zodiac    David Fincher
# 8804   s8805    Movie            Zombieland  Ruben Fleischer
# 8805   s8806    Movie                  Zoom     Peter Hewitt
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...  United States
# ...

# %% [markdown]
# 8.In how many movies/shows, Kevin James was cast?

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data[data['cast']=="Kevin James"]
# Out:
#      show_id   type                               title      director  \
# 4092   s4093  Movie  Kevin James: Sweat the Small Stuff   Paul Miller
# 4919   s4920  Movie    Kevin James: Never Don't Give Up  Andy Fickman
#
#              cast        country         date_added  release_year rating  \
# 4092  Kevin James  United States  February 20, 2019          2001  TV-PG
# 4919  Kevin James  United States     April 24, 2018          2018  TV-PG
#
#      duration        listed_in  \
# 4092   42 min  Stand-Up Comedy
# 4919   62 min  Stand-Up Comedy
#
#                                             description  \
# 4092  The film and television star riffs on life's m...
# 4919  Kevin James makes his long-awaited return to s...
#
#                             Data_N
# 4092 1970-01-01 00:00:00.000002001
# 4919 1970-01-01 00:00:00.000002018

# %%
data[data['cast'].str.contains('Kevin James')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 data[data['cast'].str.contains('Kevin James')]
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4080, in DataFrame.__getitem__(self, key)
#    4077     return self.where(key)
#    4079 # Do we have a (boolean) 1d indexer?
# -> 4080 if com.is_bool_indexer(key):
#    4081     return self._getitem_bool_array(key)
#    4083 # We are left with two options: a single key, and a collection of keys,
#    4084 # We interpret tuples as collections only for non-MultiIndex
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\common.py:136, in is_bool_indexer(key)
#     132     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     133     if lib.is_bool_array(key_array, skipna=True):
# ...

# %% [markdown]
# creating new dataframe beacuse of to delete null values rows

# %%
data_new=data.dropna()

# %%
data_new.head(2)
# Out:
#   show_id     type                          title         director  \
# 7      s8    Movie                        Sankofa     Haile Gerima
# 8      s9  TV Show  The Great British Baking Show  Andy Devonshire
#
#                                                 cast  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country          date_added  \
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
#
#    release_year rating   duration  \
# 7          1993  TV-MA    125 min
# 8          2021  TV-14  9 Seasons
#
#                                           listed_in  \
# 7  Dramas, Independent Movies, International Movies
# 8                      British TV Shows, Reality TV
#
#                                          description  \
# ...

# %%
data_new[data_new['cast'].str.contains('Kevin James')]
# Out:
#      show_id   type                                      title  \
# 27       s28  Movie                                  Grown Ups
# 1616   s1617  Movie                              Monster House
# 1879   s1880  Movie                            Hubie Halloween
# 4092   s4093  Movie         Kevin James: Sweat the Small Stuff
# 4919   s4920  Movie           Kevin James: Never Don't Give Up
# 5533   s5534  Movie                               Sandy Wexler
# 5719   s5720  Movie  True Memoirs of an International Assassin
# 6977   s6978  Movie                                      Hitch
# 7008   s7009  Movie      Hotel Transylvania 3: Summer Vacation
# 7716   s7717  Movie                       Paul Blart: Mall Cop
#
#                 director                                               cast  \
# 27          Dennis Dugan  Adam Sandler, Kevin James, Chris Rock, David S...
# 1616           Gil Kenan  Mitchel Musso, Sam Lerner, Spencer Locke, Stev...
# ...

# %% [markdown]
# 9.What are the different ratings defined by netflix

# %% [markdown]
# nuunique()

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  \
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
#
#                          Data_N
# 0 1970-01-01 00:00:00.000002020
# ...

# %%
data['rating'].nunique()  # it give number of unique number
# Out:
# 17

# %% [markdown]
# unique()

# %%
data['rating'].unique()
#data['rating'].unique().tolist()
# Out:
# ['PG-13',
#  'TV-MA',
#  'PG',
#  'TV-14',
#  'TV-PG',
#  'TV-Y',
#  'TV-Y7',
#  'R',
#  'TV-G',
#  'G',
#  'NC-17',
#  '74 min',
#  '84 min',
#  '66 min',
#  'NR',
#  nan,
#  'TV-Y7-FV',
#  'UR']

# %% [markdown]
# 9.1: how many movies got the 'TV-14' rating in Canada?

# %%
data.head()
#data.drop(columns=['Data_N'],inplace=True)      drop a column permanently
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data[(data['type']=="Movie") & (data['rating']=="TV-14")].shape
# Out:
# (1427, 12)

# %%
data[(data['type']=="Movie") & (data['rating']=="TV-14") & (data['country']=="Canada")].shape
# Out:
# (13, 12)

# %% [markdown]
# 9.2: how many TV shows got the "R" rating, after year 2015?

# %%
data[(data['type']=="TV Show") & (data['rating']=="R")]
# Out:
#      show_id     type                                title           director  \
# 3893   s3894  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
# 7593   s7594  TV Show                                Nobel                NaN
#
#                                                    cast country  \
# 3893  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
# 7593  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway
#
#              date_added  release_year rating  duration  \
# 3893     April 25, 2019          2015      R  1 Season
# 7593  December 10, 2016          2016      R  1 Season
#
#                                             listed_in  \
# 3893                                         TV Shows
# 7593  International TV Shows, TV Dramas, TV Thrillers
#
#                                             description
# 3893  Trapped at a stagecoach stop as a storm rages ...
# 7593  A series of incidents in Afghanistan set compl...

# %%
data[(data['type']=="TV Show") & (data['rating']=="R") & (data['release_year']>2015)]
# Out:
#      show_id     type  title director  \
# 7593   s7594  TV Show  Nobel      NaN
#
#                                                    cast country  \
# 7593  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway
#
#              date_added  release_year rating  duration  \
# 7593  December 10, 2016          2016      R  1 Season
#
#                                             listed_in  \
# 7593  International TV Shows, TV Dramas, TV Thrillers
#
#                                             description
# 7593  A series of incidents in Afghanistan set compl...

# %% [markdown]
# 10.what is the maximum duration of a Movie/show on Netflix?

# %%
data['duration'].unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %%
data.duration.dtype
# Out:
# dtype('O')

# %% [markdown]
# str.split()

# %%
data[['minutes','init']]=data['duration'].str.split(' ',expand=True)  # creating two columns for splitting the duration

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description minutes     init
# 0  As her father nears the end of his life, filmm...      90      min
# 1  After crossing paths at a party, a Cape Town t...       2  Seasons

# %%
data['minutes']=pd.to_numeric(data['minutes'])   # convert to numeric then we get max value

# %%
data['minutes'].max()
# Out:
# 312.0

# %%
data['minutes'].min()
# Out:
# 1.0

# %%
data['minutes'].mean()
# Out:
# 69.84688777828259

# %%
data['minutes'].median()
# Out:
# 88.0

# %%
data.dtypes
# Out:
# show_id          object
# type             object
# title            object
# director         object
# cast             object
# country          object
# date_added       object
# release_year      int64
# rating           object
# duration         object
# listed_in        object
# description      object
# minutes         float64
# init             object
# dtype: object

# %% [markdown]
# 11.which individual country has the Highest No.of TV Shows?

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  minutes     init
# 0  As her father nears the end of his life, filmm...     90.0      min
# 1  After crossing paths at a party, a Cape Town t...      2.0  Seasons

# %%
data_tvshow=data[data['type']=="TV Show"]   # get all tv show

# %%
data_tvshow.head(2)
# Out:
#   show_id     type          title         director  \
# 1      s2  TV Show  Blood & Water              NaN
# 2      s3  TV Show      Ganglands  Julien Leclercq
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description  minutes     init
# 1  After crossing paths at a party, a Cape Town t...      2.0  Seasons
# 2  To protect his family from a powerful drug lor...      1.0   Season

# %%
data_tvshow['country'].value_counts()
# Out:
# country
# United States                                    760
# United Kingdom                                   213
# Japan                                            169
# South Korea                                      158
# India                                             79
#                                                 ...
# Belarus                                            1
# United Kingdom, Australia                          1
# France, Australia, Germany                         1
# Australia, New Zealand, United States              1
# United States, France, South Korea, Indonesia      1
# Name: count, Length: 196, dtype: int64

# %%
data_tvshow.country.value_counts().head(1)
# Out:
# country
# United States    760
# Name: count, dtype: int64

# %% [markdown]
# 12. How can we sort the dataset by year?

# %%
data.sort_values(by='release_year').head(4) #ascending order
# Out:
#      show_id     type                                          title  \
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
#
#          director                       cast        country  \
# 4250          NaN                        NaN            NaN
# 7790  Frank Capra                        NaN  United States
# 8205    John Ford  Henry Fonda, Jane Darwell  United States
# 8660    John Ford                        NaN  United States
#
#              date_added  release_year rating  duration  \
# 4250  December 30, 2018          1925  TV-14  1 Season
# 7790     March 31, 2017          1942  TV-14    52 min
# 8205     March 31, 2017          1942  TV-14    18 min
# 8660     March 31, 2017          1943  TV-PG    61 min
#
# ...

# %%
data.sort_values(by="release_year",ascending=False).head(4)
# Out:
#     show_id     type                                  title        director  \
# 693    s694    Movie                 Ali & Ratu Ratu Queens  Lucky Kuswandi
# 781    s782    Movie  Black Holes | The Edge of All We Know   Peter Galison
# 762    s763    Movie                           Sweet & Sour   Lee Kae-byeok
# 763    s764  TV Show                            Sweet Tooth             NaN
#
#                                                   cast        country  \
# 693  Iqbaal Ramadhan, Nirina Zubir, Asri Welas, Tik...            NaN
# 781                                                NaN            NaN
# 762          Jang Ki-yong, Chae Soo-bin, Jung Soo-jung    South Korea
# 763  Nonso Anozie, Christian Convery, Adeel Akhtar,...  United States
#
#         date_added  release_year rating  duration  \
# 693  June 17, 2021          2021  TV-14   101 min
# 781   June 2, 2021          2021  TV-14    99 min
# 762   June 4, 2021          2021  TV-14   103 min
# ...

# %% [markdown]
# 13.Find the all the instances where:
#
# Type is 'Movie' and Listed_in is "Dramas"
#
# or
#
# Type is TV Show and Listed_in is Kids' TV

# %%
data[(data['type']=="Movie") & (data['listed_in']=="Dramas")].head(3)
# Out:
#     show_id   type               title             director  \
# 112    s113  Movie               Worth       Sara Colangelo
# 129    s130  Movie  An Unfinished Life      Lasse Hallström
# 142    s143  Movie     Freedom Writers  Richard LaGravenese
#
#                                                   cast  \
# 112  Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...
# 129  Robert Redford, Jennifer Lopez, Morgan Freeman...
# 142  Hilary Swank, Patrick Dempsey, Scott Glenn, Im...
#
#                     country         date_added  release_year rating duration  \
# 112                     NaN  September 3, 2021          2021  PG-13  119 min
# 129  Germany, United States  September 1, 2021          2005  PG-13  108 min
# 142  Germany, United States  September 1, 2021          2007  PG-13  124 min
#
#     listed_in                                        description  minutes init
# 112    Dramas  In the wake of the Sept. 11 attacks, a lawyer ...    119.0  min
# ...

# %%
data[(data['type']=="TV Show") & (data['listed_in']=="Kids' TV")].head(3)
# Out:
#    show_id     type                    title director  \
# 34     s35  TV Show  Tayo and Little Wizards      NaN
# 39     s40  TV Show             Chhota Bheem      NaN
# 65     s66  TV Show             Numberblocks      NaN
#
#                                                  cast         country  \
# 34  Dami Lee, Jason Lee, Bommie Catherine Han, Jen...             NaN
# 39  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...           India
# 65  Beth Chalmers, David Holt, Marcel McCalla, Ter...  United Kingdom
#
#             date_added  release_year rating   duration listed_in  \
# 34  September 17, 2021          2020  TV-Y7   1 Season  Kids' TV
# 39  September 16, 2021          2021  TV-Y7  3 Seasons  Kids' TV
# 65  September 15, 2021          2021   TV-Y  6 Seasons  Kids' TV
#
#                                           description  minutes     init
# 34  Tayo speeds into an adventure when his friends...      1.0   Season
# ...

# %%
data[((data['type']=="Movie") & (data['listed_in']=="Dramas")) | ((data['type']=="TV Show") & (data['listed_in']=="Kids' TV"))].head(3)
# Out:
#    show_id     type                    title director  \
# 34     s35  TV Show  Tayo and Little Wizards      NaN
# 39     s40  TV Show             Chhota Bheem      NaN
# 65     s66  TV Show             Numberblocks      NaN
#
#                                                  cast         country  \
# 34  Dami Lee, Jason Lee, Bommie Catherine Han, Jen...             NaN
# 39  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...           India
# 65  Beth Chalmers, David Holt, Marcel McCalla, Ter...  United Kingdom
#
#             date_added  release_year rating   duration listed_in  \
# 34  September 17, 2021          2020  TV-Y7   1 Season  Kids' TV
# 39  September 16, 2021          2021  TV-Y7  3 Seasons  Kids' TV
# 65  September 15, 2021          2021   TV-Y  6 Seasons  Kids' TV
#
#                                           description  minutes     init
# 34  Tayo speeds into an adventure when his friends...      1.0   Season
# ...

# %% [markdown]
# Strings functions

# %% [markdown]
# 1.str.lower()

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %% [markdown]
# pandas functions

# %% [markdown]
# value_counts()

# %%
data['release_year'].value_counts()
# Out:
# release_year
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: count, Length: 74, dtype: int64

# %% [markdown]
# where()- to filter based on condition

# %%
data.where(data['release_year']>2020) # here we are getting NaN values if the condition is not matched
data.where(data['release_year']>2020,other=0) # NaN replace with 0
data.where(data['release_year']>2020,other=0).all(1)
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool
